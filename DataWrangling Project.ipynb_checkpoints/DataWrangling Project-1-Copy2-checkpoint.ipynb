# %%
import os, re
import pandas as pd
import missingno as msno

# CURRENT DIRECTORY (PLACE SCRIPT IN /home/mydirectory)
cd = os.getcwd()

# %%
fileNames=[]
reviewRegex = re.compile(r'newest_rev(ie|ei)ws')

# %%
i = 0
columns = range(1,100)
dfList = []

for root, dirs, files in os.walk(cd):
    for fname in files:
        if reviewRegex.search(fname):
            frame = pd.read_csv(os.path.join(root, fname), names=columns,skiprows=1)
            if fname.find("EDUCATION") != -1:
                frame['CATEGORY'] = "EDUCATION"
            elif fname.find("FINANCE") !=-1:
                frame['CATEGORY'] = "FINANCE"  
            elif fname.find("ENTERTAINMENT") != -1:
                frame['CATEGORY'] = "ENTERTAINMENT"
            elif fname.find("FAMILY") != -1:
                frame['CATEGORY'] = "FAMILY"
            elif fname.find("GAME") != -1:
                frame['CATEGORY'] = "GAME-ACTION"
            elif fname.find("HEALTH") != -1:
                frame['CATEGORY'] = "HEALTH AND FITNESS"
            elif fname.find("LIFESTYLE") != -1:
                frame['CATEGORY'] = "LIFESTYLE"
            elif fname.find("MUSIC") != -1:
                frame['CATEGORY'] = "MUSIC AND AUDIO"
            
            #frame['key'] = "file{}".format(i)
            dfList.append(frame)    
            fileNames.append(fname)
            i += 1

# %%
detailsRegex = re.compile(r'_all_detailed')
i = 0
columns = range(1,100)
detailsFiles=[]
detailsList=[]



for root, dirs, files in os.walk(cd):
    for fname in files:
        if detailsRegex.search(fname):
            frame = pd.read_csv(os.path.join(root, fname), names=columns,skiprows=0)
            if fname.find("EDUCATION") != -1:
                frame['CATEGORY'] = "EDUCATION"
            elif fname.find("FINANCE") !=-1:
                frame['CATEGORY'] = "FINANCE"  
            elif fname.find("ENTERTAINMENT") != -1:
                frame['CATEGORY'] = "ENTERTAINMENT"
            elif fname.find("FAMILY") != -1:
                frame['CATEGORY'] = "FAMILY"
            elif fname.find("GAME") != -1:
                frame['CATEGORY'] = "GAME-ACTION"
            elif fname.find("HEALTH") != -1:
                frame['CATEGORY'] = "HEALTH AND FITNESS"
            elif fname.find("LIFESTYLE") != -1:
                frame['CATEGORY'] = "LIFESTYLE"
            elif fname.find("MUSIC") != -1:
                frame['CATEGORY'] = "MUSIC AND AUDIO"
            
            #frame['key'] = "file{}".format(i)
            detailsList.append(frame)    
            detailsFiles.append(fname)
            i += 1

# %%
detailsRegex = re.compile(r'2019-04-21_all_detailed')
i = 0
columns = range(1,100)
detailsFiles=[]
detailsList=[]



for root, dirs, files in os.walk(cd):
    for fname in files:
        if detailsRegex.search(fname):
            frame = pd.read_csv(os.path.join(root, fname), names=columns,skiprows=0)
            if fname.find("EDUCATION") != -1:
                frame['CATEGORY'] = "EDUCATION"
            elif fname.find("FINANCE") !=-1:
                frame['CATEGORY'] = "FINANCE"  
            elif fname.find("ENTERTAINMENT") != -1:
                frame['CATEGORY'] = "ENTERTAINMENT"
            elif fname.find("FAMILY") != -1:
                frame['CATEGORY'] = "FAMILY"
            elif fname.find("GAME") != -1:
                frame['CATEGORY'] = "GAME-ACTION"
            elif fname.find("HEALTH") != -1:
                frame['CATEGORY'] = "HEALTH AND FITNESS"
            elif fname.find("LIFESTYLE") != -1:
                frame['CATEGORY'] = "LIFESTYLE"
            elif fname.find("MUSIC") != -1:
                frame['CATEGORY'] = "MUSIC AND AUDIO"
            
            #frame['key'] = "file{}".format(i)
            detailsList.append(frame)    
            detailsFiles.append(fname)
            i += 1

# %%
len(detailsList)
# Out:
# 64

# %%
detailsDf = pd.concat(detailsList)

# %%
detailsDf
# Out:
#                                              1  \
# 0                                     appTitle
# 1               Duolingo: Learn Languages Free
# 2                                    Photomath
# 3                 Remind: School Communication
# 4                                      Kahoot!
# ..                                         ...
# 6   iHeartRadio - Free Music, Radio & Podcasts
# 7                                 Amazon Music
# 8                                 Amazon Alexa
# 9                                  Apple Music
# 10                  SoundCloud - Music & Audio
#
#                                                     2  \
# 0                                             summary
# 1   Learn English, Spanish, French, German, Italia...
# 2                                 Scan. Solve. Learn.
# 3                                School Communication
# 4   Create and play quizzes on the go, have fun an...
# ..                                                ...
# 6             com.clearchannel.iheartradio.controller
# 7                                      com.amazon.mp3
# 8                                  com.amazon.dee.app
# 9                             com.apple.android.music
# 10                             com.soundcloud.android
#
#                                                     3  \
# 0                                            installs
# 1                                        100,000,000+
# 2                                         50,000,000+
# 3                                         10,000,000+
# 4                                         10,000,000+
# ..                                                ...
# 6   https://play.google.com/store/apps/details?id=...
# 7   https://play.google.com/store/apps/details?id=...
# 8   https://play.google.com/store/apps/details?id=...
# 9   https://play.google.com/store/apps/details?id=...
# 10  https://play.google.com/store/apps/details?id=...
#
#                                                     4                  5  \
# 0                                         minInstalls              score
# 1                                           100000000          4.7198496
# 2                                            50000000           4.689265
# 3                                            10000000          4.4903703
# 4                                            10000000          4.2366056
# ..                                                ...                ...
# 6   https://lh3.googleusercontent.com/w-uA-J1kngql...  iHeartMedia, Inc.
# 7   https://lh3.googleusercontent.com/c0uMGe9aLRQx...  Amazon Mobile LLC
# 8   https://lh3.googleusercontent.com/TrGtH5xYMUuy...  Amazon Mobile LLC
# 9   https://lh3.googleusercontent.com/-E-jAfuwURMb...         Apple Inc.
# 10  https://lh3.googleusercontent.com/lvYCdrPNFU0A...         SoundCloud
#
#                       6        7     8  \
# 0               ratings  reviews  free
# 1               7258463  2788387  true
# 2               1033063   385731  true
# 3                139258    45845  true
# 4                 59838    18498  true
# ..                  ...      ...   ...
# 6   8821283674927730745     FREE  true
# 7     Amazon Mobile LLC     FREE  true
# 8     Amazon Mobile LLC     FREE  true
# 9            Apple Inc.     FREE  true
# 10           SoundCloud     FREE  true
#
#                                                     9                  10  \
# 0                                           offersIAP                size
# 1                                                true  Varies with device
# 2                                               false  Varies with device
# 3                                               false                 22M
# 4                                                true  Varies with device
# ..                                                ...                 ...
# 6   Your Music. Your Stations. Your Podcasts. All ...                 4.7
# 7   Find and play music you love – get the free Am...                 4.3
# 8        ALWAYS READY, CONNECTED, AND FAST. Just ask.                 3.4
# 9                      50 million songs. All ad-free.                 3.5
# 10  The world’s largest audio and music streaming ...                 4.5
#
#     ...  91  92  93  94  95  96  97  98  99         CATEGORY
# 0   ... NaN NaN NaN NaN NaN NaN NaN NaN NaN        EDUCATION
# 1   ... NaN NaN NaN NaN NaN NaN NaN NaN NaN        EDUCATION
# 2   ... NaN NaN NaN NaN NaN NaN NaN NaN NaN        EDUCATION
# 3   ... NaN NaN NaN NaN NaN NaN NaN NaN NaN        EDUCATION
# 4   ... NaN NaN NaN NaN NaN NaN NaN NaN NaN        EDUCATION
# ..  ...  ..  ..  ..  ..  ..  ..  ..  ..  ..              ...
# 6   ... NaN NaN NaN NaN NaN NaN NaN NaN NaN  MUSIC AND AUDIO
# 7   ... NaN NaN NaN NaN NaN NaN NaN NaN NaN  MUSIC AND AUDIO
# 8   ... NaN NaN NaN NaN NaN NaN NaN NaN NaN  MUSIC AND AUDIO
# 9   ... NaN NaN NaN NaN NaN NaN NaN NaN NaN  MUSIC AND AUDIO
# 10  ... NaN NaN NaN NaN NaN NaN NaN NaN NaN  MUSIC AND AUDIO
#
# [701 rows x 100 columns]

# %%
detailsDf.columns = detailsDf.iloc[0]

# %%
msno.matrix(detailsDf)

# %%
detailsDf.dropna(axis=1,how="all",inplace=True)

# %%
pd.set_option('display.max_columns', 30)

# %%
detailsDf.tail()
detailsDf = detailsDf.loc[:, detailsDf.columns.notnull()]

# %%
detailsDf
# Out:
# 0                                     appTitle  \
# 0                                     appTitle
# 1               Duolingo: Learn Languages Free
# 2                                    Photomath
# 3                 Remind: School Communication
# 4                                      Kahoot!
# ..                                         ...
# 6   iHeartRadio - Free Music, Radio & Podcasts
# 7                                 Amazon Music
# 8                                 Amazon Alexa
# 9                                  Apple Music
# 10                  SoundCloud - Music & Audio
#
# 0                                             summary  \
# 0                                             summary
# 1   Learn English, Spanish, French, German, Italia...
# 2                                 Scan. Solve. Learn.
# 3                                School Communication
# 4   Create and play quizzes on the go, have fun an...
# ..                                                ...
# 6             com.clearchannel.iheartradio.controller
# 7                                      com.amazon.mp3
# 8                                  com.amazon.dee.app
# 9                             com.apple.android.music
# 10                             com.soundcloud.android
#
# 0                                            installs  \
# 0                                            installs
# 1                                        100,000,000+
# 2                                         50,000,000+
# 3                                         10,000,000+
# 4                                         10,000,000+
# ..                                                ...
# 6   https://play.google.com/store/apps/details?id=...
# 7   https://play.google.com/store/apps/details?id=...
# 8   https://play.google.com/store/apps/details?id=...
# 9   https://play.google.com/store/apps/details?id=...
# 10  https://play.google.com/store/apps/details?id=...
#
# 0                                         minInstalls              score  \
# 0                                         minInstalls              score
# 1                                           100000000          4.7198496
# 2                                            50000000           4.689265
# 3                                            10000000          4.4903703
# 4                                            10000000          4.2366056
# ..                                                ...                ...
# 6   https://lh3.googleusercontent.com/w-uA-J1kngql...  iHeartMedia, Inc.
# 7   https://lh3.googleusercontent.com/c0uMGe9aLRQx...  Amazon Mobile LLC
# 8   https://lh3.googleusercontent.com/TrGtH5xYMUuy...  Amazon Mobile LLC
# 9   https://lh3.googleusercontent.com/-E-jAfuwURMb...         Apple Inc.
# 10  https://lh3.googleusercontent.com/lvYCdrPNFU0A...         SoundCloud
#
# 0               ratings  reviews  free  \
# 0               ratings  reviews  free
# 1               7258463  2788387  true
# 2               1033063   385731  true
# 3                139258    45845  true
# 4                 59838    18498  true
# ..                  ...      ...   ...
# 6   8821283674927730745     FREE  true
# 7     Amazon Mobile LLC     FREE  true
# 8     Amazon Mobile LLC     FREE  true
# 9            Apple Inc.     FREE  true
# 10           SoundCloud     FREE  true
#
# 0                                           offersIAP                size  \
# 0                                           offersIAP                size
# 1                                                true  Varies with device
# 2                                               false  Varies with device
# 3                                               false                 22M
# 4                                                true  Varies with device
# ..                                                ...                 ...
# 6   Your Music. Your Stations. Your Podcasts. All ...                 4.7
# 7   Find and play music you love – get the free Am...                 4.3
# 8        ALWAYS READY, CONNECTED, AND FAST. Just ask.                 3.4
# 9                      50 million songs. All ad-free.                 3.5
# 10  The world’s largest audio and music streaming ...                 4.5
#
# 0   androidVersionText          developerId    genreId     familyGenreId  \
# 0   androidVersionText          developerId    genreId     familyGenreId
# 1   Varies with device  6957685454452609502  EDUCATION  FAMILY_EDUCATION
# 2   Varies with device  8492011720422545772  EDUCATION               NaN
# 3           4.4 and up            Remind101  EDUCATION               NaN
# 4   Varies with device  5643238107618943124  EDUCATION  FAMILY_EDUCATION
# ..                 ...                  ...        ...               ...
# 6     4.6609664"title"                appId        url              icon
# 7      4.323581"title"                appId        url              icon
# 8     3.4326818"title"                appId        url              icon
# 9     3.4576716"title"                appId        url              icon
# 10            4.508015                  NaN        NaN               NaN
#
# 0   contentRating  adSupported      released        updated  \
# 0   contentRating  adSupported      released        updated
# 1        Everyone         true  May 29, 2013  1551998991000
# 2        Everyone        false  Feb 26, 2015  1545376427000
# 3        Everyone        false   Oct 5, 2012  1551835573000
# 4        Everyone        false   Nov 1, 2012  1551194923000
# ..            ...          ...           ...            ...
# 6       developer  developerId     priceText           free
# 7       developer  developerId     priceText           free
# 8       developer  developerId     priceText           free
# 9       developer  developerId     priceText           free
# 10            NaN          NaN           NaN            NaN
#
# 0              version                                      recentChanges  \
# 0              version                                      recentChanges
# 1   Varies with device  Our mascot owl, Duo, is trading in his usual d...
# 2   Varies with device  Bug fixes and performance enhancements for smo...
# 3         9.16.2.33150  To make your Remind experience great, we updat...
# 4   Varies with device  This update is mostly about bug fixing and imp...
# ..                 ...                                                ...
# 6              summary                                          scoreText
# 7              summary                                          scoreText
# 8              summary                                          scoreText
# 9              summary                                          scoreText
# 10                 NaN                                                NaN
#
# 0                         appId  \
# 0                         appId
# 1                  com.duolingo
# 2      com.microblink.photomath
# 3                 com.remind101
# 4   no.mobitroll.kahoot.android
# ..                          ...
# 6                         score
# 7                         score
# 8                         score
# 9                         score
# 10                          NaN
#
# 0                                                 url        EDUCATION
# 0                                                 url        EDUCATION
# 1   https://play.google.com/store/apps/details?id=...        EDUCATION
# 2   https://play.google.com/store/apps/details?id=...        EDUCATION
# 3   https://play.google.com/store/apps/details?id=...        EDUCATION
# 4   https://play.google.com/store/apps/details?id=...        EDUCATION
# ..                                                ...              ...
# 6                                                 NaN  MUSIC AND AUDIO
# 7                                                 NaN  MUSIC AND AUDIO
# 8                                                 NaN  MUSIC AND AUDIO
# 9                                                 NaN  MUSIC AND AUDIO
# 10                                                NaN  MUSIC AND AUDIO
#
# [701 rows x 23 columns]

# %%
#detailsDf.dropna(axis=1,thresh=72,inplace=True)
# Out:
# C:\Users\shahi\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
detailsDf.reset_index(drop=True,inplace=True)

# %%
detailsDf
# Out:
# 0                                      appTitle  \
# 0                                      appTitle
# 1                Duolingo: Learn Languages Free
# 2                                     Photomath
# 3                  Remind: School Communication
# 4                                       Kahoot!
# ..                                          ...
# 696  iHeartRadio - Free Music, Radio & Podcasts
# 697                                Amazon Music
# 698                                Amazon Alexa
# 699                                 Apple Music
# 700                  SoundCloud - Music & Audio
#
# 0                                              summary  \
# 0                                              summary
# 1    Learn English, Spanish, French, German, Italia...
# 2                                  Scan. Solve. Learn.
# 3                                 School Communication
# 4    Create and play quizzes on the go, have fun an...
# ..                                                 ...
# 696            com.clearchannel.iheartradio.controller
# 697                                     com.amazon.mp3
# 698                                 com.amazon.dee.app
# 699                            com.apple.android.music
# 700                             com.soundcloud.android
#
# 0                                             installs  \
# 0                                             installs
# 1                                         100,000,000+
# 2                                          50,000,000+
# 3                                          10,000,000+
# 4                                          10,000,000+
# ..                                                 ...
# 696  https://play.google.com/store/apps/details?id=...
# 697  https://play.google.com/store/apps/details?id=...
# 698  https://play.google.com/store/apps/details?id=...
# 699  https://play.google.com/store/apps/details?id=...
# 700  https://play.google.com/store/apps/details?id=...
#
# 0                                          minInstalls              score  \
# 0                                          minInstalls              score
# 1                                            100000000          4.7198496
# 2                                             50000000           4.689265
# 3                                             10000000          4.4903703
# 4                                             10000000          4.2366056
# ..                                                 ...                ...
# 696  https://lh3.googleusercontent.com/w-uA-J1kngql...  iHeartMedia, Inc.
# 697  https://lh3.googleusercontent.com/c0uMGe9aLRQx...  Amazon Mobile LLC
# 698  https://lh3.googleusercontent.com/TrGtH5xYMUuy...  Amazon Mobile LLC
# 699  https://lh3.googleusercontent.com/-E-jAfuwURMb...         Apple Inc.
# 700  https://lh3.googleusercontent.com/lvYCdrPNFU0A...         SoundCloud
#
# 0                ratings  reviews  free  \
# 0                ratings  reviews  free
# 1                7258463  2788387  true
# 2                1033063   385731  true
# 3                 139258    45845  true
# 4                  59838    18498  true
# ..                   ...      ...   ...
# 696  8821283674927730745     FREE  true
# 697    Amazon Mobile LLC     FREE  true
# 698    Amazon Mobile LLC     FREE  true
# 699           Apple Inc.     FREE  true
# 700           SoundCloud     FREE  true
#
# 0                                            offersIAP                size  \
# 0                                            offersIAP                size
# 1                                                 true  Varies with device
# 2                                                false  Varies with device
# 3                                                false                 22M
# 4                                                 true  Varies with device
# ..                                                 ...                 ...
# 696  Your Music. Your Stations. Your Podcasts. All ...                 4.7
# 697  Find and play music you love – get the free Am...                 4.3
# 698       ALWAYS READY, CONNECTED, AND FAST. Just ask.                 3.4
# 699                     50 million songs. All ad-free.                 3.5
# 700  The world’s largest audio and music streaming ...                 4.5
#
# 0    androidVersionText          developerId    genreId     familyGenreId  \
# 0    androidVersionText          developerId    genreId     familyGenreId
# 1    Varies with device  6957685454452609502  EDUCATION  FAMILY_EDUCATION
# 2    Varies with device  8492011720422545772  EDUCATION               NaN
# 3            4.4 and up            Remind101  EDUCATION               NaN
# 4    Varies with device  5643238107618943124  EDUCATION  FAMILY_EDUCATION
# ..                  ...                  ...        ...               ...
# 696    4.6609664"title"                appId        url              icon
# 697     4.323581"title"                appId        url              icon
# 698    3.4326818"title"                appId        url              icon
# 699    3.4576716"title"                appId        url              icon
# 700            4.508015                  NaN        NaN               NaN
#
# 0    contentRating  adSupported      released        updated  \
# 0    contentRating  adSupported      released        updated
# 1         Everyone         true  May 29, 2013  1551998991000
# 2         Everyone        false  Feb 26, 2015  1545376427000
# 3         Everyone        false   Oct 5, 2012  1551835573000
# 4         Everyone        false   Nov 1, 2012  1551194923000
# ..             ...          ...           ...            ...
# 696      developer  developerId     priceText           free
# 697      developer  developerId     priceText           free
# 698      developer  developerId     priceText           free
# 699      developer  developerId     priceText           free
# 700            NaN          NaN           NaN            NaN
#
# 0               version                                      recentChanges  \
# 0               version                                      recentChanges
# 1    Varies with device  Our mascot owl, Duo, is trading in his usual d...
# 2    Varies with device  Bug fixes and performance enhancements for smo...
# 3          9.16.2.33150  To make your Remind experience great, we updat...
# 4    Varies with device  This update is mostly about bug fixing and imp...
# ..                  ...                                                ...
# 696             summary                                          scoreText
# 697             summary                                          scoreText
# 698             summary                                          scoreText
# 699             summary                                          scoreText
# 700                 NaN                                                NaN
#
# 0                          appId  \
# 0                          appId
# 1                   com.duolingo
# 2       com.microblink.photomath
# 3                  com.remind101
# 4    no.mobitroll.kahoot.android
# ..                           ...
# 696                        score
# 697                        score
# 698                        score
# 699                        score
# 700                          NaN
#
# 0                                                  url        EDUCATION
# 0                                                  url        EDUCATION
# 1    https://play.google.com/store/apps/details?id=...        EDUCATION
# 2    https://play.google.com/store/apps/details?id=...        EDUCATION
# 3    https://play.google.com/store/apps/details?id=...        EDUCATION
# 4    https://play.google.com/store/apps/details?id=...        EDUCATION
# ..                                                 ...              ...
# 696                                                NaN  MUSIC AND AUDIO
# 697                                                NaN  MUSIC AND AUDIO
# 698                                                NaN  MUSIC AND AUDIO
# 699                                                NaN  MUSIC AND AUDIO
# 700                                                NaN  MUSIC AND AUDIO
#
# [701 rows x 23 columns]

# %%
detailsDf.drop(index=0,inplace=True)
# Out:
# C:\Users\shahi\Anaconda3\lib\site-packages\pandas\core\frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
detailsDf[detailsDf["appTitle"] == "title"]
# Out:
# 0   appTitle summary installs minInstalls      score      ratings    reviews  \
# 527    title   appId      url        icon  developer  developerId  priceText
# 538    title   appId      url        icon  developer  developerId  priceText
# 549    title   appId      url        icon  developer  developerId  priceText
# 560    title   appId      url        icon  developer  developerId  priceText
# 571    title   appId      url        icon  developer  developerId  priceText
# 582    title   appId      url        icon  developer  developerId  priceText
# 593    title   appId      url        icon  developer  developerId  priceText
# 603    title   appId      url        icon  developer  developerId  priceText
# 614    title   appId      url        icon  developer  developerId  priceText
# 625    title   appId      url        icon  developer  developerId  priceText
# 636    title   appId      url        icon  developer  developerId  priceText
# 647    title   appId      url        icon  developer  developerId  priceText
# 658    title   appId      url        icon  developer  developerId  priceText
# 669    title   appId      url        icon  developer  developerId  priceText
# 680    title   appId      url        icon  developer  developerId  priceText
# 690    title   appId      url        icon  developer  developerId  priceText
#
# 0    free offersIAP       size androidVersionText developerId genreId  \
# 527  free   summary  scoreText              score         NaN     NaN
# 538  free   summary  scoreText              score         NaN     NaN
# 549  free   summary  scoreText              score         NaN     NaN
# 560  free   summary  scoreText              score         NaN     NaN
# 571  free   summary  scoreText              score         NaN     NaN
# 582  free   summary  scoreText              score         NaN     NaN
# 593  free   summary  scoreText              score         NaN     NaN
# 603  free   summary  scoreText              score         NaN     NaN
# 614  free   summary  scoreText              score         NaN     NaN
# 625  free   summary  scoreText              score         NaN     NaN
# 636  free   summary  scoreText              score         NaN     NaN
# 647  free   summary  scoreText              score         NaN     NaN
# 658  free   summary  scoreText              score         NaN     NaN
# 669  free   summary  scoreText              score         NaN     NaN
# 680  free   summary  scoreText              score         NaN     NaN
# 690  free   summary  scoreText              score         NaN     NaN
#
# 0   familyGenreId contentRating adSupported released updated version  \
# 527           NaN           NaN         NaN      NaN     NaN     NaN
# 538           NaN           NaN         NaN      NaN     NaN     NaN
# 549           NaN           NaN         NaN      NaN     NaN     NaN
# 560           NaN           NaN         NaN      NaN     NaN     NaN
# 571           NaN           NaN         NaN      NaN     NaN     NaN
# 582           NaN           NaN         NaN      NaN     NaN     NaN
# 593           NaN           NaN         NaN      NaN     NaN     NaN
# 603           NaN           NaN         NaN      NaN     NaN     NaN
# 614           NaN           NaN         NaN      NaN     NaN     NaN
# 625           NaN           NaN         NaN      NaN     NaN     NaN
# 636           NaN           NaN         NaN      NaN     NaN     NaN
# 647           NaN           NaN         NaN      NaN     NaN     NaN
# 658           NaN           NaN         NaN      NaN     NaN     NaN
# 669           NaN           NaN         NaN      NaN     NaN     NaN
# 680           NaN           NaN         NaN      NaN     NaN     NaN
# 690           NaN           NaN         NaN      NaN     NaN     NaN
#
# 0   recentChanges appId  url           EDUCATION
# 527           NaN   NaN  NaN           EDUCATION
# 538           NaN   NaN  NaN       ENTERTAINMENT
# 549           NaN   NaN  NaN              FAMILY
# 560           NaN   NaN  NaN             FINANCE
# 571           NaN   NaN  NaN         GAME-ACTION
# 582           NaN   NaN  NaN  HEALTH AND FITNESS
# 593           NaN   NaN  NaN           LIFESTYLE
# 603           NaN   NaN  NaN     MUSIC AND AUDIO
# 614           NaN   NaN  NaN           EDUCATION
# 625           NaN   NaN  NaN       ENTERTAINMENT
# 636           NaN   NaN  NaN              FAMILY
# 647           NaN   NaN  NaN             FINANCE
# 658           NaN   NaN  NaN         GAME-ACTION
# 669           NaN   NaN  NaN  HEALTH AND FITNESS
# 680           NaN   NaN  NaN           LIFESTYLE
# 690           NaN   NaN  NaN     MUSIC AND AUDIO

# %%
detailsDf.drop(index=527,inplace=True)

# %%
apps = detailsDf.appTitle.unique().tolist()

# %%
apps.sort()

# %%
indexName = detailsDf[detailsDf["appTitle"] == 'Bitmoji – your Personal Emoji'].index
detailsDf.drop(index=indexName,inplace=True)
# Out:
# C:\Users\shahi\Anaconda3\lib\site-packages\pandas\core\frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
len(detailsDf.appTitle.str.lower().unique())
# Out:
# 88

# %%
len(detailsDf.appTitle.unique())
# Out:
# 89

# %%
apps
# Out:
# ['ABCmouse.com',
#  'Amazon Alexa',
#  'Amazon Music',
#  'Amazon Prime Video',
#  'Apple Music',
#  'Ball Mayhem!',
#  'Bank of America Mobile Banking',
#  'Battle Royale: FPS Shooter',
#  'Bitmoji – Your Personal Emoji',
#  'Bitmoji – your personal emoji',
#  'Bowmasters',
#  'CVS/pharmacy',
#  'Calm - Meditate, Sleep, Relax',
#  'Calorie Counter - MyFitnessPal',
#  'Cash App',
#  'Chase Mobile',
#  'ClassDojo',
#  'Color by Number, Pixel Color - Pixel Art',
#  'Credit Karma',
#  'DisneyNOW – Episodes & Live TV',
#  'Drink Water Reminder: Water Tracker & Alarm',
#  'Drum Pad Machine - Make Beats',
#  'Duolingo: Learn Languages Free',
#  'FaceApp',
#  'Family Locator - GPS Tracker',
#  'Fantastic Face – Daily face & Beauty Competition',
#  'Fantastic Face – Face Analysis & Aging Prediction',
#  'Fitbit',
#  'Free Music Player – Online & Offline MP3 Player',
#  'Fresh EBT - Food Stamp Balance',
#  'Google Classroom',
#  'Google Home',
#  'Google Play Games',
#  'Headspace: Meditation & Sleep',
#  'Helix Jump',
#  'Horoscope Prediction - Zodiac Signs Astrology',
#  'Hulu: Stream TV, Movies & more',
#  'IRS2Go',
#  'Kahoot!',
#  'Kick the Buddy',
#  'Lose Belly Fat in 30 Days - Flat Stomach',
#  'Lose It! - Calorie Counter',
#  'Love Poly - New puzzle game',
#  'Minion Rush: Despicable Me Official Game',
#  'Ms.Sibyl - See Future Me',
#  'Netflix',
#  'Notepad - Notes with Reminder, ToDo, Sticky notes',
#  'PBS KIDS Video',
#  'PUBG MOBILE',
#  'Pandora - Streaming Music & Podcasts',
#  'Pandora Music',
#  'PayPal Mobile Cash: Send and Request Money Fast',
#  'Photomath',
#  'Pinkfong Baby Shark',
#  'Pixel Art: Color by Number',
#  'Pixel Art: Color by Number, Pixel Color',
#  'Pixel Art: Color by Number, Pixel Color(Pixel Pop)',
#  'Pluto TV - It’s Free TV',
#  'Quizlet: Learn Languages & Vocab with Flashcards',
#  'Remind: School Communication',
#  'Roblox',
#  'Roku',
#  'STARZ',
#  'Samsung Health',
#  'SmartThings',
#  'Sniper 3D Gun Shooter: Free Elite Shooting Games',
#  'Sniper 3D Gun Shooter: Free Shooting Games - FPS',
#  'Snowball.io',
#  'SoundCloud - Music & Audio',
#  'Spotify - Music and Podcasts',
#  'Super Bino Go - New Games 2019',
#  'Sweatcoin Pays You To Get Fit',
#  'Tag with Ryan',
#  'The PCH App',
#  'Tinder',
#  'Toca Kitchen 2',
#  'Tomb of the Mask',
#  'Tubi - Free Movies & TV Shows',
#  'TurboTax Tax Return App – Max Refund Guaranteed',
#  'Unicorn Slime Maker and Simulator',
#  'Venmo Mobile Wallet: Send & Receive Money',
#  'WildCraft: Animal Sim Online 3D',
#  'YouTube Kids',
#  'YouTube Music - Stream Songs & Music Videos',
#  'Zelle',
#  'appTitle',
#  'iHeartRadio - Free Music, Radio & Podcasts',
#  'slither.io']

# %%
detailsDf[detailsDf["appTitle"] == 'Bitmoji – Your Personal Emoji']
# Out:
# 0                         appTitle  \
# 49   Bitmoji – Your Personal Emoji
# 104  Bitmoji – Your Personal Emoji
# 192  Bitmoji – Your Personal Emoji
# 280  Bitmoji – Your Personal Emoji
#
# 0                                              summary      installs  \
# 49   Bitmoji is your personal emoji. Use it in Snap...  100,000,000+
# 104  Bitmoji is your personal emoji. Use it in Snap...  100,000,000+
# 192  Bitmoji is your personal emoji. Use it in Snap...  100,000,000+
# 280  Bitmoji is your personal emoji. Use it in Snap...  100,000,000+
#
# 0   minInstalls      score  ratings  reviews  free offersIAP  \
# 49    100000000  4.6259613  2764113  1003433  true      true
# 104   100000000   4.625942  2780016  1012348  true      true
# 192   100000000  4.6259837  2791420  1018647  true      true
# 280   100000000    4.62598  2799119  1022882  true      true
#
# 0                  size  ... familyGenreId contentRating adSupported  \
# 49   Varies with device  ...           NaN          Teen       false
# 104  Varies with device  ...           NaN          Teen       false
# 192  Varies with device  ...           NaN          Teen       false
# 280  Varies with device  ...           NaN          Teen       false
#
# 0        released        updated             version  \
# 49   Oct 28, 2014  1551978101000  Varies with device
# 104  Oct 28, 2014  1553102778000  Varies with device
# 192  Oct 28, 2014  1553889612000  Varies with device
# 280  Oct 28, 2014  1554304389000  Varies with device
#
# 0                                recentChanges                appId  \
# 49   * Bug fixes and performance improvements.  com.bitstrips.imoji
# 104    Bug fixes and performance improvements.  com.bitstrips.imoji
# 192    Bug fixes and performance improvements.  com.bitstrips.imoji
# 280    Bug fixes and performance improvements.  com.bitstrips.imoji
#
# 0                                                  url      EDUCATION
# 49   https://play.google.com/store/apps/details?id=...  ENTERTAINMENT
# 104  https://play.google.com/store/apps/details?id=...  ENTERTAINMENT
# 192  https://play.google.com/store/apps/details?id=...  ENTERTAINMENT
# 280  https://play.google.com/store/apps/details?id=...  ENTERTAINMENT
#
# [4 rows x 23 columns]

# %%
detailsDf.appTitle.unique()
# Out:
# array(['Duolingo: Learn Languages Free', 'Photomath',
#        'Remind: School Communication', 'Kahoot!', 'Google Classroom',
#        'ABCmouse.com', 'ClassDojo', 'PBS KIDS Video',
#        'Quizlet: Learn Languages & Vocab with Flashcards',
#        'Pinkfong Baby Shark', 'appTitle', 'Cash App',
#        'Venmo Mobile Wallet: Send & Receive Money', 'IRS2Go',
#        'PayPal Mobile Cash: Send and Request Money Fast', 'Credit Karma',
#        'TurboTax Tax Return App – Max Refund Guaranteed',
#        'Bank of America Mobile Banking', 'Chase Mobile', 'Zelle',
#        'Fresh EBT - Food Stamp Balance', 'Tomb of the Mask', 'Helix Jump',
#        'Ball Mayhem!', 'Kick the Buddy', 'PUBG MOBILE', 'Snowball.io',
#        'Sniper 3D Gun Shooter: Free Shooting Games - FPS', 'slither.io',
#        'Bowmasters', 'Battle Royale: FPS Shooter', 'Pandora Music',
#        'Spotify - Music and Podcasts',
#        'YouTube Music - Stream Songs & Music Videos',
#        'Free Music Player – Online & Offline MP3 Player',
#        'Drum Pad Machine - Make Beats',
#        'iHeartRadio - Free Music, Radio & Podcasts', 'Amazon Music',
#        'Amazon Alexa', 'Apple Music', 'SoundCloud - Music & Audio',
#        'Netflix', 'Pixel Art: Color by Number, Pixel Color(Pixel Pop)',
#        'Google Play Games', 'Hulu: Stream TV, Movies & more',
#        'Bitmoji – Your Personal Emoji', 'Amazon Prime Video',
#        'Pluto TV - It’s Free TV', 'STARZ',
#        'Tubi - Free Movies & TV Shows', 'Roku', 'Roblox',
#        'Love Poly - New puzzle game', 'Tag with Ryan',
#        'Super Bino Go - New Games 2019', 'YouTube Kids', 'Toca Kitchen 2',
#        'WildCraft: Animal Sim Online 3D',
#        'Minion Rush: Despicable Me Official Game',
#        'DisneyNOW – Episodes & Live TV', 'Family Locator - GPS Tracker',
#        'Google Home', 'Tinder', 'SmartThings', 'Ms.Sibyl - See Future Me',
#        'Fantastic Face – Face Analysis & Aging Prediction',
#        'Horoscope Prediction - Zodiac Signs Astrology', 'The PCH App',
#        'Notepad - Notes with Reminder, ToDo, Sticky notes',
#        'Unicorn Slime Maker and Simulator',
#        'Sweatcoin Pays You To Get Fit', 'Calm - Meditate, Sleep, Relax',
#        'Samsung Health', 'Fitbit', 'Calorie Counter - MyFitnessPal',
#        'Lose Belly Fat in 30 Days - Flat Stomach',
#        'Headspace: Meditation & Sleep',
#        'Drink Water Reminder: Water Tracker & Alarm', 'CVS/pharmacy',
#        'Lose It! - Calorie Counter',
#        'Sniper 3D Gun Shooter: Free Elite Shooting Games',
#        'Pixel Art: Color by Number, Pixel Color', 'FaceApp',
#        'Color by Number, Pixel Color - Pixel Art',
#        'Fantastic Face – Daily face & Beauty Competition',
#        'Pixel Art: Color by Number', 'Bitmoji – your personal emoji',
#        'Pandora - Streaming Music & Podcasts'], dtype=object)

# %%
detailsDf
# Out:
# 0                                      appTitle  \
# 1                Duolingo: Learn Languages Free
# 2                                     Photomath
# 3                  Remind: School Communication
# 4                                       Kahoot!
# 5                              Google Classroom
# ..                                          ...
# 696  iHeartRadio - Free Music, Radio & Podcasts
# 697                                Amazon Music
# 698                                Amazon Alexa
# 699                                 Apple Music
# 700                  SoundCloud - Music & Audio
#
# 0                                              summary  \
# 1    Learn English, Spanish, French, German, Italia...
# 2                                  Scan. Solve. Learn.
# 3                                 School Communication
# 4    Create and play quizzes on the go, have fun an...
# 5    Connect with your classes and do assignments o...
# ..                                                 ...
# 696            com.clearchannel.iheartradio.controller
# 697                                     com.amazon.mp3
# 698                                 com.amazon.dee.app
# 699                            com.apple.android.music
# 700                             com.soundcloud.android
#
# 0                                             installs  \
# 1                                         100,000,000+
# 2                                          50,000,000+
# 3                                          10,000,000+
# 4                                          10,000,000+
# 5                                          10,000,000+
# ..                                                 ...
# 696  https://play.google.com/store/apps/details?id=...
# 697  https://play.google.com/store/apps/details?id=...
# 698  https://play.google.com/store/apps/details?id=...
# 699  https://play.google.com/store/apps/details?id=...
# 700  https://play.google.com/store/apps/details?id=...
#
# 0                                          minInstalls              score  \
# 1                                            100000000          4.7198496
# 2                                             50000000           4.689265
# 3                                             10000000          4.4903703
# 4                                             10000000          4.2366056
# 5                                             10000000           4.230005
# ..                                                 ...                ...
# 696  https://lh3.googleusercontent.com/w-uA-J1kngql...  iHeartMedia, Inc.
# 697  https://lh3.googleusercontent.com/c0uMGe9aLRQx...  Amazon Mobile LLC
# 698  https://lh3.googleusercontent.com/TrGtH5xYMUuy...  Amazon Mobile LLC
# 699  https://lh3.googleusercontent.com/-E-jAfuwURMb...         Apple Inc.
# 700  https://lh3.googleusercontent.com/lvYCdrPNFU0A...         SoundCloud
#
# 0                ratings  reviews  free  \
# 1                7258463  2788387  true
# 2                1033063   385731  true
# 3                 139258    45845  true
# 4                  59838    18498  true
# 5                  87020    22630  true
# ..                   ...      ...   ...
# 696  8821283674927730745     FREE  true
# 697    Amazon Mobile LLC     FREE  true
# 698    Amazon Mobile LLC     FREE  true
# 699           Apple Inc.     FREE  true
# 700           SoundCloud     FREE  true
#
# 0                                            offersIAP                size  \
# 1                                                 true  Varies with device
# 2                                                false  Varies with device
# 3                                                false                 22M
# 4                                                 true  Varies with device
# 5                                                false  Varies with device
# ..                                                 ...                 ...
# 696  Your Music. Your Stations. Your Podcasts. All ...                 4.7
# 697  Find and play music you love – get the free Am...                 4.3
# 698       ALWAYS READY, CONNECTED, AND FAST. Just ask.                 3.4
# 699                     50 million songs. All ad-free.                 3.5
# 700  The world’s largest audio and music streaming ...                 4.5
#
# 0    ...     familyGenreId contentRating  adSupported      released  \
# 1    ...  FAMILY_EDUCATION      Everyone         true  May 29, 2013
# 2    ...               NaN      Everyone        false  Feb 26, 2015
# 3    ...               NaN      Everyone        false   Oct 5, 2012
# 4    ...  FAMILY_EDUCATION      Everyone        false   Nov 1, 2012
# 5    ...               NaN      Everyone        false  Jan 14, 2015
# ..   ...               ...           ...          ...           ...
# 696  ...              icon     developer  developerId     priceText
# 697  ...              icon     developer  developerId     priceText
# 698  ...              icon     developer  developerId     priceText
# 699  ...              icon     developer  developerId     priceText
# 700  ...               NaN           NaN          NaN           NaN
#
# 0          updated             version  \
# 1    1551998991000  Varies with device
# 2    1545376427000  Varies with device
# 3    1551835573000        9.16.2.33150
# 4    1551194923000  Varies with device
# 5    1550592218000  Varies with device
# ..             ...                 ...
# 696           free             summary
# 697           free             summary
# 698           free             summary
# 699           free             summary
# 700            NaN                 NaN
#
# 0                                        recentChanges  \
# 1    Our mascot owl, Duo, is trading in his usual d...
# 2    Bug fixes and performance enhancements for smo...
# 3    To make your Remind experience great, we updat...
# 4    This update is mostly about bug fixing and imp...
# 5    We&#39;re making classes even more flexible fo...
# ..                                                 ...
# 696                                          scoreText
# 697                                          scoreText
# 698                                          scoreText
# 699                                          scoreText
# 700                                                NaN
#
# 0                                appId  \
# 1                         com.duolingo
# 2             com.microblink.photomath
# 3                        com.remind101
# 4          no.mobitroll.kahoot.android
# 5    com.google.android.apps.classroom
# ..                                 ...
# 696                              score
# 697                              score
# 698                              score
# 699                              score
# 700                                NaN
#
# 0                                                  url        EDUCATION
# 1    https://play.google.com/store/apps/details?id=...        EDUCATION
# 2    https://play.google.com/store/apps/details?id=...        EDUCATION
# 3    https://play.google.com/store/apps/details?id=...        EDUCATION
# 4    https://play.google.com/store/apps/details?id=...        EDUCATION
# 5    https://play.google.com/store/apps/details?id=...        EDUCATION
# ..                                                 ...              ...
# 696                                                NaN  MUSIC AND AUDIO
# 697                                                NaN  MUSIC AND AUDIO
# 698                                                NaN  MUSIC AND AUDIO
# 699                                                NaN  MUSIC AND AUDIO
# 700                                                NaN  MUSIC AND AUDIO
#
# [636 rows x 23 columns]

# %%
detailsDf.drop_duplicates(subset=['appTitle','summary','installs','minInstalls','score','ratings','reviews','free','offersIAP','size','androidVersionText','developerId','genreId','familyGenreId','contentRating'],inplace=True)
# Out:
# C:\Users\shahi\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
len(detailsDf.appTitle.unique())
# Out:
# 89

# %%
detailsDf.rename(columns={"EDUCATION":"CATEGORY"},inplace=True)
# Out:
# C:\Users\shahi\Anaconda3\lib\site-packages\pandas\core\frame.py:4223: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(**kwargs)

# %%
detailsDf
#detailsDf["CATEGORY"] = detailsDf["CATEGORY"]
# Out:
# 0                                      appTitle  \
# 0                                      appTitle
# 1                Duolingo: Learn Languages Free
# 2                                     Photomath
# 3                  Remind: School Communication
# 4                                       Kahoot!
# ..                                          ...
# 696  iHeartRadio - Free Music, Radio & Podcasts
# 697                                Amazon Music
# 698                                Amazon Alexa
# 699                                 Apple Music
# 700                  SoundCloud - Music & Audio
#
# 0                                              summary  \
# 0                                              summary
# 1    Learn English, Spanish, French, German, Italia...
# 2                                  Scan. Solve. Learn.
# 3                                 School Communication
# 4    Create and play quizzes on the go, have fun an...
# ..                                                 ...
# 696            com.clearchannel.iheartradio.controller
# 697                                     com.amazon.mp3
# 698                                 com.amazon.dee.app
# 699                            com.apple.android.music
# 700                             com.soundcloud.android
#
# 0                                             installs  \
# 0                                             installs
# 1                                         100,000,000+
# 2                                          50,000,000+
# 3                                          10,000,000+
# 4                                          10,000,000+
# ..                                                 ...
# 696  https://play.google.com/store/apps/details?id=...
# 697  https://play.google.com/store/apps/details?id=...
# 698  https://play.google.com/store/apps/details?id=...
# 699  https://play.google.com/store/apps/details?id=...
# 700  https://play.google.com/store/apps/details?id=...
#
# 0                                          minInstalls              score  \
# 0                                          minInstalls              score
# 1                                            100000000          4.7198496
# 2                                             50000000           4.689265
# 3                                             10000000          4.4903703
# 4                                             10000000          4.2366056
# ..                                                 ...                ...
# 696  https://lh3.googleusercontent.com/w-uA-J1kngql...  iHeartMedia, Inc.
# 697  https://lh3.googleusercontent.com/c0uMGe9aLRQx...  Amazon Mobile LLC
# 698  https://lh3.googleusercontent.com/TrGtH5xYMUuy...  Amazon Mobile LLC
# 699  https://lh3.googleusercontent.com/-E-jAfuwURMb...         Apple Inc.
# 700  https://lh3.googleusercontent.com/lvYCdrPNFU0A...         SoundCloud
#
# 0                ratings  reviews  free  \
# 0                ratings  reviews  free
# 1                7258463  2788387  true
# 2                1033063   385731  true
# 3                 139258    45845  true
# 4                  59838    18498  true
# ..                   ...      ...   ...
# 696  8821283674927730745     FREE  true
# 697    Amazon Mobile LLC     FREE  true
# 698    Amazon Mobile LLC     FREE  true
# 699           Apple Inc.     FREE  true
# 700           SoundCloud     FREE  true
#
# 0                                            offersIAP                size  \
# 0                                            offersIAP                size
# 1                                                 true  Varies with device
# 2                                                false  Varies with device
# 3                                                false                 22M
# 4                                                 true  Varies with device
# ..                                                 ...                 ...
# 696  Your Music. Your Stations. Your Podcasts. All ...                 4.7
# 697  Find and play music you love – get the free Am...                 4.3
# 698       ALWAYS READY, CONNECTED, AND FAST. Just ask.                 3.4
# 699                     50 million songs. All ad-free.                 3.5
# 700  The world’s largest audio and music streaming ...                 4.5
#
# 0    androidVersionText          developerId    genreId     familyGenreId  \
# 0    androidVersionText          developerId    genreId     familyGenreId
# 1    Varies with device  6957685454452609502  EDUCATION  FAMILY_EDUCATION
# 2    Varies with device  8492011720422545772  EDUCATION               NaN
# 3            4.4 and up            Remind101  EDUCATION               NaN
# 4    Varies with device  5643238107618943124  EDUCATION  FAMILY_EDUCATION
# ..                  ...                  ...        ...               ...
# 696    4.6609664"title"                appId        url              icon
# 697     4.323581"title"                appId        url              icon
# 698    3.4326818"title"                appId        url              icon
# 699    3.4576716"title"                appId        url              icon
# 700            4.508015                  NaN        NaN               NaN
#
# 0    contentRating  adSupported      released        updated  \
# 0    contentRating  adSupported      released        updated
# 1         Everyone         true  May 29, 2013  1551998991000
# 2         Everyone        false  Feb 26, 2015  1545376427000
# 3         Everyone        false   Oct 5, 2012  1551835573000
# 4         Everyone        false   Nov 1, 2012  1551194923000
# ..             ...          ...           ...            ...
# 696      developer  developerId     priceText           free
# 697      developer  developerId     priceText           free
# 698      developer  developerId     priceText           free
# 699      developer  developerId     priceText           free
# 700            NaN          NaN           NaN            NaN
#
# 0               version                                      recentChanges  \
# 0               version                                      recentChanges
# 1    Varies with device  Our mascot owl, Duo, is trading in his usual d...
# 2    Varies with device  Bug fixes and performance enhancements for smo...
# 3          9.16.2.33150  To make your Remind experience great, we updat...
# 4    Varies with device  This update is mostly about bug fixing and imp...
# ..                  ...                                                ...
# 696             summary                                          scoreText
# 697             summary                                          scoreText
# 698             summary                                          scoreText
# 699             summary                                          scoreText
# 700                 NaN                                                NaN
#
# 0                          appId  \
# 0                          appId
# 1                   com.duolingo
# 2       com.microblink.photomath
# 3                  com.remind101
# 4    no.mobitroll.kahoot.android
# ..                           ...
# 696                        score
# 697                        score
# 698                        score
# 699                        score
# 700                          NaN
#
# 0                                                  url         CATEGORY
# 0                                                  url        EDUCATION
# 1    https://play.google.com/store/apps/details?id=...        EDUCATION
# 2    https://play.google.com/store/apps/details?id=...        EDUCATION
# 3    https://play.google.com/store/apps/details?id=...        EDUCATION
# 4    https://play.google.com/store/apps/details?id=...        EDUCATION
# ..                                                 ...              ...
# 696                                                NaN  MUSIC AND AUDIO
# 697                                                NaN  MUSIC AND AUDIO
# 698                                                NaN  MUSIC AND AUDIO
# 699                                                NaN  MUSIC AND AUDIO
# 700                                                NaN  MUSIC AND AUDIO
#
# [637 rows x 23 columns]

# %%
#detailsDf.reset_index(drop=True,inplace=True)

# %%
detailsDf
# Out:
# 0                                      appTitle  \
# 1                Duolingo: Learn Languages Free
# 2                                     Photomath
# 3                  Remind: School Communication
# 4                                       Kahoot!
# 5                              Google Classroom
# ..                                          ...
# 696  iHeartRadio - Free Music, Radio & Podcasts
# 697                                Amazon Music
# 698                                Amazon Alexa
# 699                                 Apple Music
# 700                  SoundCloud - Music & Audio
#
# 0                                              summary  \
# 1    Learn English, Spanish, French, German, Italia...
# 2                                  Scan. Solve. Learn.
# 3                                 School Communication
# 4    Create and play quizzes on the go, have fun an...
# 5    Connect with your classes and do assignments o...
# ..                                                 ...
# 696            com.clearchannel.iheartradio.controller
# 697                                     com.amazon.mp3
# 698                                 com.amazon.dee.app
# 699                            com.apple.android.music
# 700                             com.soundcloud.android
#
# 0                                             installs  \
# 1                                         100,000,000+
# 2                                          50,000,000+
# 3                                          10,000,000+
# 4                                          10,000,000+
# 5                                          10,000,000+
# ..                                                 ...
# 696  https://play.google.com/store/apps/details?id=...
# 697  https://play.google.com/store/apps/details?id=...
# 698  https://play.google.com/store/apps/details?id=...
# 699  https://play.google.com/store/apps/details?id=...
# 700  https://play.google.com/store/apps/details?id=...
#
# 0                                          minInstalls              score  \
# 1                                            100000000          4.7198496
# 2                                             50000000           4.689265
# 3                                             10000000          4.4903703
# 4                                             10000000          4.2366056
# 5                                             10000000           4.230005
# ..                                                 ...                ...
# 696  https://lh3.googleusercontent.com/w-uA-J1kngql...  iHeartMedia, Inc.
# 697  https://lh3.googleusercontent.com/c0uMGe9aLRQx...  Amazon Mobile LLC
# 698  https://lh3.googleusercontent.com/TrGtH5xYMUuy...  Amazon Mobile LLC
# 699  https://lh3.googleusercontent.com/-E-jAfuwURMb...         Apple Inc.
# 700  https://lh3.googleusercontent.com/lvYCdrPNFU0A...         SoundCloud
#
# 0                ratings  reviews  free  \
# 1                7258463  2788387  true
# 2                1033063   385731  true
# 3                 139258    45845  true
# 4                  59838    18498  true
# 5                  87020    22630  true
# ..                   ...      ...   ...
# 696  8821283674927730745     FREE  true
# 697    Amazon Mobile LLC     FREE  true
# 698    Amazon Mobile LLC     FREE  true
# 699           Apple Inc.     FREE  true
# 700           SoundCloud     FREE  true
#
# 0                                            offersIAP                size  \
# 1                                                 true  Varies with device
# 2                                                false  Varies with device
# 3                                                false                 22M
# 4                                                 true  Varies with device
# 5                                                false  Varies with device
# ..                                                 ...                 ...
# 696  Your Music. Your Stations. Your Podcasts. All ...                 4.7
# 697  Find and play music you love – get the free Am...                 4.3
# 698       ALWAYS READY, CONNECTED, AND FAST. Just ask.                 3.4
# 699                     50 million songs. All ad-free.                 3.5
# 700  The world’s largest audio and music streaming ...                 4.5
#
# 0    androidVersionText          developerId    genreId     familyGenreId  \
# 1    Varies with device  6957685454452609502  EDUCATION  FAMILY_EDUCATION
# 2    Varies with device  8492011720422545772  EDUCATION               NaN
# 3            4.4 and up            Remind101  EDUCATION               NaN
# 4    Varies with device  5643238107618943124  EDUCATION  FAMILY_EDUCATION
# 5    Varies with device  5700313618786177705  EDUCATION               NaN
# ..                  ...                  ...        ...               ...
# 696    4.6609664"title"                appId        url              icon
# 697     4.323581"title"                appId        url              icon
# 698    3.4326818"title"                appId        url              icon
# 699    3.4576716"title"                appId        url              icon
# 700            4.508015                  NaN        NaN               NaN
#
# 0   contentRating  adSupported      released        updated  \
# 1        Everyone         true  May 29, 2013  1551998991000
# 2        Everyone        false  Feb 26, 2015  1545376427000
# 3        Everyone        false   Oct 5, 2012  1551835573000
# 4        Everyone        false   Nov 1, 2012  1551194923000
# 5        Everyone        false  Jan 14, 2015  1550592218000
# ..            ...          ...           ...            ...
# 696     developer  developerId     priceText           free
# 697     developer  developerId     priceText           free
# 698     developer  developerId     priceText           free
# 699     developer  developerId     priceText           free
# 700           NaN          NaN           NaN            NaN
#
# 0               version                                      recentChanges  \
# 1    Varies with device  Our mascot owl, Duo, is trading in his usual d...
# 2    Varies with device  Bug fixes and performance enhancements for smo...
# 3          9.16.2.33150  To make your Remind experience great, we updat...
# 4    Varies with device  This update is mostly about bug fixing and imp...
# 5    Varies with device  We&#39;re making classes even more flexible fo...
# ..                  ...                                                ...
# 696             summary                                          scoreText
# 697             summary                                          scoreText
# 698             summary                                          scoreText
# 699             summary                                          scoreText
# 700                 NaN                                                NaN
#
# 0                                appId  \
# 1                         com.duolingo
# 2             com.microblink.photomath
# 3                        com.remind101
# 4          no.mobitroll.kahoot.android
# 5    com.google.android.apps.classroom
# ..                                 ...
# 696                              score
# 697                              score
# 698                              score
# 699                              score
# 700                                NaN
#
# 0                                                  url         CATEGORY
# 1    https://play.google.com/store/apps/details?id=...        EDUCATION
# 2    https://play.google.com/store/apps/details?id=...        EDUCATION
# 3    https://play.google.com/store/apps/details?id=...        EDUCATION
# 4    https://play.google.com/store/apps/details?id=...        EDUCATION
# 5    https://play.google.com/store/apps/details?id=...        EDUCATION
# ..                                                 ...              ...
# 696                                                NaN  MUSIC AND AUDIO
# 697                                                NaN  MUSIC AND AUDIO
# 698                                                NaN  MUSIC AND AUDIO
# 699                                                NaN  MUSIC AND AUDIO
# 700                                                NaN  MUSIC AND AUDIO
#
# [637 rows x 23 columns]

# %%
#drop_A = detailsDf.index[detailsDf["appTitle"] == "appTitle"].tolist()
#drop_A

# %%
# drop_A = detailsDf.index[detailsDf["appTitle"] == "appTitle"].tolist()
# #for i in drop_A:
# detailsDf = detailsDf.drop(detailsDf.index[drop_A])

# %%
#detailsDf.reset_index(drop=True,inplace=True)

# %%
detailsDf
# Out:
# 0                                      appTitle  \
# 1                Duolingo: Learn Languages Free
# 2                                     Photomath
# 3                  Remind: School Communication
# 4                                       Kahoot!
# 5                              Google Classroom
# ..                                          ...
# 696  iHeartRadio - Free Music, Radio & Podcasts
# 697                                Amazon Music
# 698                                Amazon Alexa
# 699                                 Apple Music
# 700                  SoundCloud - Music & Audio
#
# 0                                              summary  \
# 1    Learn English, Spanish, French, German, Italia...
# 2                                  Scan. Solve. Learn.
# 3                                 School Communication
# 4    Create and play quizzes on the go, have fun an...
# 5    Connect with your classes and do assignments o...
# ..                                                 ...
# 696            com.clearchannel.iheartradio.controller
# 697                                     com.amazon.mp3
# 698                                 com.amazon.dee.app
# 699                            com.apple.android.music
# 700                             com.soundcloud.android
#
# 0                                             installs  \
# 1                                         100,000,000+
# 2                                          50,000,000+
# 3                                          10,000,000+
# 4                                          10,000,000+
# 5                                          10,000,000+
# ..                                                 ...
# 696  https://play.google.com/store/apps/details?id=...
# 697  https://play.google.com/store/apps/details?id=...
# 698  https://play.google.com/store/apps/details?id=...
# 699  https://play.google.com/store/apps/details?id=...
# 700  https://play.google.com/store/apps/details?id=...
#
# 0                                          minInstalls              score  \
# 1                                            100000000          4.7198496
# 2                                             50000000           4.689265
# 3                                             10000000          4.4903703
# 4                                             10000000          4.2366056
# 5                                             10000000           4.230005
# ..                                                 ...                ...
# 696  https://lh3.googleusercontent.com/w-uA-J1kngql...  iHeartMedia, Inc.
# 697  https://lh3.googleusercontent.com/c0uMGe9aLRQx...  Amazon Mobile LLC
# 698  https://lh3.googleusercontent.com/TrGtH5xYMUuy...  Amazon Mobile LLC
# 699  https://lh3.googleusercontent.com/-E-jAfuwURMb...         Apple Inc.
# 700  https://lh3.googleusercontent.com/lvYCdrPNFU0A...         SoundCloud
#
# 0                ratings  reviews  free  \
# 1                7258463  2788387  true
# 2                1033063   385731  true
# 3                 139258    45845  true
# 4                  59838    18498  true
# 5                  87020    22630  true
# ..                   ...      ...   ...
# 696  8821283674927730745     FREE  true
# 697    Amazon Mobile LLC     FREE  true
# 698    Amazon Mobile LLC     FREE  true
# 699           Apple Inc.     FREE  true
# 700           SoundCloud     FREE  true
#
# 0                                            offersIAP                size  \
# 1                                                 true  Varies with device
# 2                                                false  Varies with device
# 3                                                false                 22M
# 4                                                 true  Varies with device
# 5                                                false  Varies with device
# ..                                                 ...                 ...
# 696  Your Music. Your Stations. Your Podcasts. All ...                 4.7
# 697  Find and play music you love – get the free Am...                 4.3
# 698       ALWAYS READY, CONNECTED, AND FAST. Just ask.                 3.4
# 699                     50 million songs. All ad-free.                 3.5
# 700  The world’s largest audio and music streaming ...                 4.5
#
# 0    androidVersionText          developerId    genreId     familyGenreId  \
# 1    Varies with device  6957685454452609502  EDUCATION  FAMILY_EDUCATION
# 2    Varies with device  8492011720422545772  EDUCATION               NaN
# 3            4.4 and up            Remind101  EDUCATION               NaN
# 4    Varies with device  5643238107618943124  EDUCATION  FAMILY_EDUCATION
# 5    Varies with device  5700313618786177705  EDUCATION               NaN
# ..                  ...                  ...        ...               ...
# 696    4.6609664"title"                appId        url              icon
# 697     4.323581"title"                appId        url              icon
# 698    3.4326818"title"                appId        url              icon
# 699    3.4576716"title"                appId        url              icon
# 700            4.508015                  NaN        NaN               NaN
#
# 0   contentRating  adSupported      released        updated  \
# 1        Everyone         true  May 29, 2013  1551998991000
# 2        Everyone        false  Feb 26, 2015  1545376427000
# 3        Everyone        false   Oct 5, 2012  1551835573000
# 4        Everyone        false   Nov 1, 2012  1551194923000
# 5        Everyone        false  Jan 14, 2015  1550592218000
# ..            ...          ...           ...            ...
# 696     developer  developerId     priceText           free
# 697     developer  developerId     priceText           free
# 698     developer  developerId     priceText           free
# 699     developer  developerId     priceText           free
# 700           NaN          NaN           NaN            NaN
#
# 0               version                                      recentChanges  \
# 1    Varies with device  Our mascot owl, Duo, is trading in his usual d...
# 2    Varies with device  Bug fixes and performance enhancements for smo...
# 3          9.16.2.33150  To make your Remind experience great, we updat...
# 4    Varies with device  This update is mostly about bug fixing and imp...
# 5    Varies with device  We&#39;re making classes even more flexible fo...
# ..                  ...                                                ...
# 696             summary                                          scoreText
# 697             summary                                          scoreText
# 698             summary                                          scoreText
# 699             summary                                          scoreText
# 700                 NaN                                                NaN
#
# 0                                appId  \
# 1                         com.duolingo
# 2             com.microblink.photomath
# 3                        com.remind101
# 4          no.mobitroll.kahoot.android
# 5    com.google.android.apps.classroom
# ..                                 ...
# 696                              score
# 697                              score
# 698                              score
# 699                              score
# 700                                NaN
#
# 0                                                  url         CATEGORY
# 1    https://play.google.com/store/apps/details?id=...        EDUCATION
# 2    https://play.google.com/store/apps/details?id=...        EDUCATION
# 3    https://play.google.com/store/apps/details?id=...        EDUCATION
# 4    https://play.google.com/store/apps/details?id=...        EDUCATION
# 5    https://play.google.com/store/apps/details?id=...        EDUCATION
# ..                                                 ...              ...
# 696                                                NaN  MUSIC AND AUDIO
# 697                                                NaN  MUSIC AND AUDIO
# 698                                                NaN  MUSIC AND AUDIO
# 699                                                NaN  MUSIC AND AUDIO
# 700                                                NaN  MUSIC AND AUDIO
#
# [637 rows x 23 columns]

# %%
len(df.appTitle.str.lower().unique())
# Out:
# 86

# %%
 detailsDf.reviews.astype("float64")
#pd.to_numeric("reviews", errors='coerce')

detailsDf.reviews = detailsDf.reviews.replace(["priceText","FREE"],np.nan)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-d970f27cd5e5> in <module>
# ----> 1 detailsDf.reviews.astype("float64")
#       2 #pd.to_numeric("reviews", errors='coerce')
#       3
#       4 detailsDf.reviews = detailsDf.reviews.replace(["priceText","FREE"],np.nan)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5880             # else, only a single dtype is given
#    5881             new_data = self._data.astype(
# -> 5882                 dtype=dtype, copy=copy, errors=errors, **kwargs
#    5883             )
#    5884             return self._constructor(new_data).__finalize__(self)
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, **kwargs)
#     579
#     580     def astype(self, dtype, **kwargs):
# --> 581         return self.apply("astype", dtype=dtype, **kwargs)
#     582
#     583     def convert(self, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#     436                     kwargs[k] = obj.reindex(b_items, axis=axis, copy=align_copy)
#     437
# --> 438             applied = getattr(b, f)(**kwargs)
#     439             result_blocks = _extend_blocks(applied, result_blocks)
#     440
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors, values, **kwargs)
#     557
#     558     def astype(self, dtype, copy=False, errors="raise", values=None, **kwargs):
# --> 559         return self._astype(dtype, copy=copy, errors=errors, values=values, **kwargs)
#     560
#     561     def _astype(self, dtype, copy=False, errors="raise", values=None, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in _astype(self, dtype, copy, errors, values, **kwargs)
#     641                     # _astype_nansafe works fine with 1-d only
#     642                     vals1d = values.ravel()
# --> 643                     values = astype_nansafe(vals1d, dtype, copy=True, **kwargs)
#     644
#     645                 # TODO(extension)
#
# ~\Anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     727     if copy or is_object_dtype(arr) or is_object_dtype(dtype):
#     728         # Explicit copy, or required since NumPy can't view from / to object.
# --> 729         return arr.astype(dtype, copy=True)
#     730
#     731     return arr.view(dtype)
#
# ValueError: could not convert string to float: 'reviews'

# %%
#detailsDf['reviews']=detailsDf['reviews'].replace('',np.nan).astype("float64")
detailsDf['reviews'] = pd.to_numeric(detailsDf['reviews'], errors='coerce')


#detailsDf['reviews'] = detailsDf['reviews'].astype('float64')
# Out:
# C:\Users\shahi\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
detailsDf.groupby("CATEGORY")["reviews"].count()
# Out:
# CATEGORY
# EDUCATION             60
# ENTERTAINMENT         60
# FAMILY                58
# FINANCE               60
# GAME-ACTION           60
# HEALTH AND FITNESS    60
# LIFESTYLE             59
# MUSIC AND AUDIO       60
# Name: reviews, dtype: int64

# %%
detailsDf
# Out:
# 0                                      appTitle  \
# 1                Duolingo: Learn Languages Free
# 2                                     Photomath
# 3                  Remind: School Communication
# 4                                       Kahoot!
# 5                              Google Classroom
# ..                                          ...
# 696  iHeartRadio - Free Music, Radio & Podcasts
# 697                                Amazon Music
# 698                                Amazon Alexa
# 699                                 Apple Music
# 700                  SoundCloud - Music & Audio
#
# 0                                              summary  \
# 1    Learn English, Spanish, French, German, Italia...
# 2                                  Scan. Solve. Learn.
# 3                                 School Communication
# 4    Create and play quizzes on the go, have fun an...
# 5    Connect with your classes and do assignments o...
# ..                                                 ...
# 696            com.clearchannel.iheartradio.controller
# 697                                     com.amazon.mp3
# 698                                 com.amazon.dee.app
# 699                            com.apple.android.music
# 700                             com.soundcloud.android
#
# 0                                             installs  \
# 1                                         100,000,000+
# 2                                          50,000,000+
# 3                                          10,000,000+
# 4                                          10,000,000+
# 5                                          10,000,000+
# ..                                                 ...
# 696  https://play.google.com/store/apps/details?id=...
# 697  https://play.google.com/store/apps/details?id=...
# 698  https://play.google.com/store/apps/details?id=...
# 699  https://play.google.com/store/apps/details?id=...
# 700  https://play.google.com/store/apps/details?id=...
#
# 0                                          minInstalls              score  \
# 1                                            100000000          4.7198496
# 2                                             50000000           4.689265
# 3                                             10000000          4.4903703
# 4                                             10000000          4.2366056
# 5                                             10000000           4.230005
# ..                                                 ...                ...
# 696  https://lh3.googleusercontent.com/w-uA-J1kngql...  iHeartMedia, Inc.
# 697  https://lh3.googleusercontent.com/c0uMGe9aLRQx...  Amazon Mobile LLC
# 698  https://lh3.googleusercontent.com/TrGtH5xYMUuy...  Amazon Mobile LLC
# 699  https://lh3.googleusercontent.com/-E-jAfuwURMb...         Apple Inc.
# 700  https://lh3.googleusercontent.com/lvYCdrPNFU0A...         SoundCloud
#
# 0                ratings  reviews  free  \
# 1                7258463  2788387  true
# 2                1033063   385731  true
# 3                 139258    45845  true
# 4                  59838    18498  true
# 5                  87020    22630  true
# ..                   ...      ...   ...
# 696  8821283674927730745      NaN  true
# 697    Amazon Mobile LLC      NaN  true
# 698    Amazon Mobile LLC      NaN  true
# 699           Apple Inc.      NaN  true
# 700           SoundCloud      NaN  true
#
# 0                                            offersIAP                size  \
# 1                                                 true  Varies with device
# 2                                                false  Varies with device
# 3                                                false                 22M
# 4                                                 true  Varies with device
# 5                                                false  Varies with device
# ..                                                 ...                 ...
# 696  Your Music. Your Stations. Your Podcasts. All ...                 4.7
# 697  Find and play music you love – get the free Am...                 4.3
# 698       ALWAYS READY, CONNECTED, AND FAST. Just ask.                 3.4
# 699                     50 million songs. All ad-free.                 3.5
# 700  The world’s largest audio and music streaming ...                 4.5
#
# 0    androidVersionText          developerId    genreId     familyGenreId  \
# 1    Varies with device  6957685454452609502  EDUCATION  FAMILY_EDUCATION
# 2    Varies with device  8492011720422545772  EDUCATION               NaN
# 3            4.4 and up            Remind101  EDUCATION               NaN
# 4    Varies with device  5643238107618943124  EDUCATION  FAMILY_EDUCATION
# 5    Varies with device  5700313618786177705  EDUCATION               NaN
# ..                  ...                  ...        ...               ...
# 696    4.6609664"title"                appId        url              icon
# 697     4.323581"title"                appId        url              icon
# 698    3.4326818"title"                appId        url              icon
# 699    3.4576716"title"                appId        url              icon
# 700            4.508015                  NaN        NaN               NaN
#
# 0   contentRating  adSupported      released        updated  \
# 1        Everyone         true  May 29, 2013  1551998991000
# 2        Everyone        false  Feb 26, 2015  1545376427000
# 3        Everyone        false   Oct 5, 2012  1551835573000
# 4        Everyone        false   Nov 1, 2012  1551194923000
# 5        Everyone        false  Jan 14, 2015  1550592218000
# ..            ...          ...           ...            ...
# 696           NaN  developerId     priceText           free
# 697           NaN  developerId     priceText           free
# 698           NaN  developerId     priceText           free
# 699           NaN  developerId     priceText           free
# 700           NaN          NaN           NaN            NaN
#
# 0               version                                      recentChanges  \
# 1    Varies with device  Our mascot owl, Duo, is trading in his usual d...
# 2    Varies with device  Bug fixes and performance enhancements for smo...
# 3          9.16.2.33150  To make your Remind experience great, we updat...
# 4    Varies with device  This update is mostly about bug fixing and imp...
# 5    Varies with device  We&#39;re making classes even more flexible fo...
# ..                  ...                                                ...
# 696             summary                                          scoreText
# 697             summary                                          scoreText
# 698             summary                                          scoreText
# 699             summary                                          scoreText
# 700                 NaN                                                NaN
#
# 0                                appId  \
# 1                         com.duolingo
# 2             com.microblink.photomath
# 3                        com.remind101
# 4          no.mobitroll.kahoot.android
# 5    com.google.android.apps.classroom
# ..                                 ...
# 696                              score
# 697                              score
# 698                              score
# 699                              score
# 700                                NaN
#
# 0                                                  url         CATEGORY
# 1    https://play.google.com/store/apps/details?id=...        EDUCATION
# 2    https://play.google.com/store/apps/details?id=...        EDUCATION
# 3    https://play.google.com/store/apps/details?id=...        EDUCATION
# 4    https://play.google.com/store/apps/details?id=...        EDUCATION
# 5    https://play.google.com/store/apps/details?id=...        EDUCATION
# ..                                                 ...              ...
# 696                                                NaN  MUSIC AND AUDIO
# 697                                                NaN  MUSIC AND AUDIO
# 698                                                NaN  MUSIC AND AUDIO
# 699                                                NaN  MUSIC AND AUDIO
# 700                                                NaN  MUSIC AND AUDIO
#
# [637 rows x 23 columns]

# %%
#detailsDf.drop_duplicates(['CATEGORY',"contentRating"])["CATEGORY"]["contentRating"]

# %%
def replaceRepeat(x):
    return re.sub(r'([a-z])\1{2,}', r'\1\1', x)
frame2['text']= frame2['text'].map(replaceRepeat)

# %%
detailsDf.groupby(["CATEGORY","contentRating"])["contentRating"].count()
# Out:
# CATEGORY            contentRating
# EDUCATION           Everyone         60
# ENTERTAINMENT       Everyone          6
#                     Mature 17+        6
#                     Teen             48
# FAMILY              Everyone         40
#                     Everyone 10+     18
# FINANCE             Everyone         60
#                     contentRating     1
# GAME-ACTION         Everyone         30
#                     Mature 17+        6
#                     Teen             24
# HEALTH AND FITNESS  Everyone         60
# LIFESTYLE           Everyone         52
#                     Mature 17+        6
#                     Teen              1
# MUSIC AND AUDIO     Everyone         12
#                     Teen             48
# Name: contentRating, dtype: int64

# %%
import numpy as np

# %%
#detailsDf.replace(to_replace="developer",value=np.nan,inplace=True)

# %%
detailsDf.groupby(["CATEGORY","contentRating"])["reviews"].sum()
# Out:
# CATEGORY            contentRating
# EDUCATION           Everyone         21187631.0
# ENTERTAINMENT       Everyone          1254289.0
#                     Mature 17+         213348.0
#                     Teen             34625967.0
# FAMILY              Everyone         16189609.0
#                     Everyone 10+     44649433.0
# FINANCE             Everyone          8368128.0
#                     contentRating           0.0
# GAME-ACTION         Everyone         24876647.0
#                     Mature 17+       19033933.0
#                     Teen             49456760.0
# HEALTH AND FITNESS  Everyone          8997622.0
# LIFESTYLE           Everyone          4202447.0
#                     Mature 17+        5091935.0
#                     Teen                 8880.0
# MUSIC AND AUDIO     Everyone           836336.0
#                     Teen             45152540.0
# Name: reviews, dtype: float64

# %%
detailsDf.loc[:,["contentRating","CATEGORY"]]
# Out:
# 0  contentRating         CATEGORY
# 0       Everyone        EDUCATION
# 1       Everyone        EDUCATION
# 2       Everyone        EDUCATION
# 3       Everyone        EDUCATION
# 4       Everyone        EDUCATION
# ..           ...              ...
# 74          Teen  MUSIC AND AUDIO
# 75          Teen  MUSIC AND AUDIO
# 76      Everyone  MUSIC AND AUDIO
# 77          Teen  MUSIC AND AUDIO
# 78          Teen  MUSIC AND AUDIO
#
# [79 rows x 2 columns]

# %% [markdown]
# #### Reviews Analysis

# %%
len(fileNames)
# Out:
# 64

# %%
df = pd.concat(dfList)

# %%
df
# Out:
#                                 1              2              3  4  \
# 0                       Photomath            NaN  March 8, 2019  5
# 1                       Photomath            NaN  March 8, 2019  4
# 2                       Photomath            NaN  March 8, 2019  5
# 3                       Photomath            NaN  March 8, 2019  5
# 4                       Photomath            NaN  March 8, 2019  1
# ...                           ...            ...            ... ..
# 44795  SoundCloud - Music & Audio  pubgmaster 25    May 3, 2019  1
# 44796  SoundCloud - Music & Audio   Anjita Sinha    May 3, 2019  4
# 44797  SoundCloud - Music & Audio     Luis Lucas    May 3, 2019  5
# 44798  SoundCloud - Music & Audio    Teairo Keys    May 3, 2019  5
# 44799  SoundCloud - Music & Audio       Ian Libo    May 3, 2019  1
#
#                                                        5   6   7   8   9  10  \
# 0                                                   nice NaN NaN NaN NaN NaN
# 1                                           very helpful NaN NaN NaN NaN NaN
# 2      Great App. Detailed answers. Understandable an... NaN NaN NaN NaN NaN
# 3                                               great!!! NaN NaN NaN NaN NaN
# 4                      bakwas hai pura.....time pass hai NaN NaN NaN NaN NaN
# ...                                                  ...  ..  ..  ..  ..  ..
# 44795                                             it gay NaN NaN NaN NaN NaN
# 44796                                            Love it NaN NaN NaN NaN NaN
# 44797  muy bueno me gusta y puedo aguardar la musica ... NaN NaN NaN NaN NaN
# 44798                                      love this app NaN NaN NaN NaN NaN
# 44799  The app was great and has a very nice selectio... NaN NaN NaN NaN NaN
#
#        ...  91  92  93  94  95  96  97  98  99         CATEGORY
# 0      ... NaN NaN NaN NaN NaN NaN NaN NaN NaN        EDUCATION
# 1      ... NaN NaN NaN NaN NaN NaN NaN NaN NaN        EDUCATION
# 2      ... NaN NaN NaN NaN NaN NaN NaN NaN NaN        EDUCATION
# 3      ... NaN NaN NaN NaN NaN NaN NaN NaN NaN        EDUCATION
# 4      ... NaN NaN NaN NaN NaN NaN NaN NaN NaN        EDUCATION
# ...    ...  ..  ..  ..  ..  ..  ..  ..  ..  ..              ...
# 44795  ... NaN NaN NaN NaN NaN NaN NaN NaN NaN  MUSIC AND AUDIO
# 44796  ... NaN NaN NaN NaN NaN NaN NaN NaN NaN  MUSIC AND AUDIO
# 44797  ... NaN NaN NaN NaN NaN NaN NaN NaN NaN  MUSIC AND AUDIO
# 44798  ... NaN NaN NaN NaN NaN NaN NaN NaN NaN  MUSIC AND AUDIO
# 44799  ... NaN NaN NaN NaN NaN NaN NaN NaN NaN  MUSIC AND AUDIO
#
# [2715303 rows x 100 columns]

# %%
df.reset_index(drop=True,inplace=True)

# %%
df.tail()
# Out:
#                                   1              2            3  4  \
# 2715298  SoundCloud - Music & Audio  pubgmaster 25  May 3, 2019  1
# 2715299  SoundCloud - Music & Audio   Anjita Sinha  May 3, 2019  4
# 2715300  SoundCloud - Music & Audio     Luis Lucas  May 3, 2019  5
# 2715301  SoundCloud - Music & Audio    Teairo Keys  May 3, 2019  5
# 2715302  SoundCloud - Music & Audio       Ian Libo  May 3, 2019  1
#
#                                                          5   6   7   8   9  \
# 2715298                                             it gay NaN NaN NaN NaN
# 2715299                                            Love it NaN NaN NaN NaN
# 2715300  muy bueno me gusta y puedo aguardar la musica ... NaN NaN NaN NaN
# 2715301                                      love this app NaN NaN NaN NaN
# 2715302  The app was great and has a very nice selectio... NaN NaN NaN NaN
#
#          10  ...  91  92  93  94  95  96  97  98  99         CATEGORY
# 2715298 NaN  ... NaN NaN NaN NaN NaN NaN NaN NaN NaN  MUSIC AND AUDIO
# 2715299 NaN  ... NaN NaN NaN NaN NaN NaN NaN NaN NaN  MUSIC AND AUDIO
# 2715300 NaN  ... NaN NaN NaN NaN NaN NaN NaN NaN NaN  MUSIC AND AUDIO
# 2715301 NaN  ... NaN NaN NaN NaN NaN NaN NaN NaN NaN  MUSIC AND AUDIO
# 2715302 NaN  ... NaN NaN NaN NaN NaN NaN NaN NaN NaN  MUSIC AND AUDIO
#
# [5 rows x 100 columns]

# %%
df.rename(columns={1:"appTitle",2:"userName",3:"date",4:"score",5:"text"},inplace=True)

# %%
df.dropna(axis=1,how="all",inplace=True)

# %% [markdown]
# #### Reviews Data set after reading each CSV and attaching category as additional column

# %%
df
# Out:
#                            appTitle       userName           date  score  \
# 0                         Photomath            NaN  March 8, 2019      5
# 1                         Photomath            NaN  March 8, 2019      4
# 2                         Photomath            NaN  March 8, 2019      5
# 3                         Photomath            NaN  March 8, 2019      5
# 4                         Photomath            NaN  March 8, 2019      1
# ...                             ...            ...            ...    ...
# 2715298  SoundCloud - Music & Audio  pubgmaster 25    May 3, 2019      1
# 2715299  SoundCloud - Music & Audio   Anjita Sinha    May 3, 2019      4
# 2715300  SoundCloud - Music & Audio     Luis Lucas    May 3, 2019      5
# 2715301  SoundCloud - Music & Audio    Teairo Keys    May 3, 2019      5
# 2715302  SoundCloud - Music & Audio       Ian Libo    May 3, 2019      1
#
#                                                       text         CATEGORY
# 0                                                     nice        EDUCATION
# 1                                             very helpful        EDUCATION
# 2        Great App. Detailed answers. Understandable an...        EDUCATION
# 3                                                 great!!!        EDUCATION
# 4                        bakwas hai pura.....time pass hai        EDUCATION
# ...                                                    ...              ...
# 2715298                                             it gay  MUSIC AND AUDIO
# 2715299                                            Love it  MUSIC AND AUDIO
# 2715300  muy bueno me gusta y puedo aguardar la musica ...  MUSIC AND AUDIO
# 2715301                                      love this app  MUSIC AND AUDIO
# 2715302  The app was great and has a very nice selectio...  MUSIC AND AUDIO
#
# [2715303 rows x 6 columns]

# %%
df.tail()
# Out:
#                            appTitle       userName         date  score  \
# 2715298  SoundCloud - Music & Audio  pubgmaster 25  May 3, 2019      1
# 2715299  SoundCloud - Music & Audio   Anjita Sinha  May 3, 2019      4
# 2715300  SoundCloud - Music & Audio     Luis Lucas  May 3, 2019      5
# 2715301  SoundCloud - Music & Audio    Teairo Keys  May 3, 2019      5
# 2715302  SoundCloud - Music & Audio       Ian Libo  May 3, 2019      1
#
#                                                       text         CATEGORY
# 2715298                                             it gay  MUSIC AND AUDIO
# 2715299                                            Love it  MUSIC AND AUDIO
# 2715300  muy bueno me gusta y puedo aguardar la musica ...  MUSIC AND AUDIO
# 2715301                                      love this app  MUSIC AND AUDIO
# 2715302  The app was great and has a very nice selectio...  MUSIC AND AUDIO

# %% [markdown]
# ##### Convert all the app title to lower to avoid any duplicates with other columns as a result of having same name but are different as a result of case sensitivity

# %%
df['appTitle'] = df['appTitle'].str.lower()

# %% [markdown]
# ##### Drop all the possible duplicates

# %%
df.drop_duplicates(subset=['appTitle','userName','date','score','text'],inplace=True)

# %%
df
# Out:
#                            appTitle       userName           date  score  \
# 0                         photomath            NaN  March 8, 2019      5
# 1                         photomath            NaN  March 8, 2019      4
# 2                         photomath            NaN  March 8, 2019      5
# 3                         photomath            NaN  March 8, 2019      5
# 4                         photomath            NaN  March 8, 2019      1
# ...                             ...            ...            ...    ...
# 2715298  soundcloud - music & audio  pubgmaster 25    May 3, 2019      1
# 2715299  soundcloud - music & audio   Anjita Sinha    May 3, 2019      4
# 2715300  soundcloud - music & audio     Luis Lucas    May 3, 2019      5
# 2715301  soundcloud - music & audio    Teairo Keys    May 3, 2019      5
# 2715302  soundcloud - music & audio       Ian Libo    May 3, 2019      1
#
#                                                       text         CATEGORY
# 0                                                     nice        EDUCATION
# 1                                             very helpful        EDUCATION
# 2        Great App. Detailed answers. Understandable an...        EDUCATION
# 3                                                 great!!!        EDUCATION
# 4                        bakwas hai pura.....time pass hai        EDUCATION
# ...                                                    ...              ...
# 2715298                                             it gay  MUSIC AND AUDIO
# 2715299                                            Love it  MUSIC AND AUDIO
# 2715300  muy bueno me gusta y puedo aguardar la musica ...  MUSIC AND AUDIO
# 2715301                                      love this app  MUSIC AND AUDIO
# 2715302  The app was great and has a very nice selectio...  MUSIC AND AUDIO
#
# [1443771 rows x 6 columns]

# %% [markdown]
# ##### Drop any duplicates that have the same app Title and text to clear out even more misleading data

# %%
df.dropna(subset=['appTitle','text'],inplace=True)

# %%
df
# Out:
#                            appTitle       userName           date  score  \
# 0                         photomath            NaN  March 8, 2019      5
# 1                         photomath            NaN  March 8, 2019      4
# 2                         photomath            NaN  March 8, 2019      5
# 3                         photomath            NaN  March 8, 2019      5
# 4                         photomath            NaN  March 8, 2019      1
# ...                             ...            ...            ...    ...
# 2715298  soundcloud - music & audio  pubgmaster 25    May 3, 2019      1
# 2715299  soundcloud - music & audio   Anjita Sinha    May 3, 2019      4
# 2715300  soundcloud - music & audio     Luis Lucas    May 3, 2019      5
# 2715301  soundcloud - music & audio    Teairo Keys    May 3, 2019      5
# 2715302  soundcloud - music & audio       Ian Libo    May 3, 2019      1
#
#                                                       text         CATEGORY
# 0                                                     nice        EDUCATION
# 1                                             very helpful        EDUCATION
# 2        Great App. Detailed answers. Understandable an...        EDUCATION
# 3                                                 great!!!        EDUCATION
# 4                        bakwas hai pura.....time pass hai        EDUCATION
# ...                                                    ...              ...
# 2715298                                             it gay  MUSIC AND AUDIO
# 2715299                                            Love it  MUSIC AND AUDIO
# 2715300  muy bueno me gusta y puedo aguardar la musica ...  MUSIC AND AUDIO
# 2715301                                      love this app  MUSIC AND AUDIO
# 2715302  The app was great and has a very nice selectio...  MUSIC AND AUDIO
#
# [1112298 rows x 6 columns]

# %% [markdown]
# ##### Total number of unique reviews

# %%
len(df.text.unique())
# Out:
# 673592

# %% [markdown]
# ##### Unique number of Apps in the dataset

# %%
len(df.appTitle.unique())
# Out:
# 86

# %% [markdown]
# ##### Number of apps in each of the specified 8 categories

# %%
df.groupby("CATEGORY")['appTitle'].nunique()
# Out:
# CATEGORY
# EDUCATION             10
# ENTERTAINMENT         13
# FAMILY                10
# FINANCE               10
# GAME-ACTION           11
# HEALTH AND FITNESS    10
# LIFESTYLE             12
# MUSIC AND AUDIO       11
# Name: appTitle, dtype: int64

# %%
len(df.CATEGORY.unique())
# Out:
# 8

# %%
len(df.appTitle.unique())
# Out:
# 86

# %%
msno.matrix(df)

# %% [markdown]
# #### Number of reviews per category

# %%
df.groupby("CATEGORY")['text'].count()
# Out:
# CATEGORY
# EDUCATION              95830
# ENTERTAINMENT         181303
# FAMILY                 98783
# FINANCE               141129
# GAME-ACTION           209493
# HEALTH AND FITNESS    109859
# LIFESTYLE             102928
# MUSIC AND AUDIO       172973
# Name: text, dtype: int64

# %%
df["processedText"] = df["text"]

# %%
def replaceRepeat(x):
    return re.sub(r'([a-z])\1{2,}', r'\1\1', x)
df['proce']= frame2['text'].map(replaceRepeat)

# %%
df.processedText.replace({r'[^\x00-\x7F]+':''}, regex=True, inplace=True)

# %%
df['processedText'] = df['processedText'].str.replace('[^\w\s]','',)

# %%
df['processedText'].apply(%recall)
# Out:
#                            appTitle       userName           date  score  \
# 0                         Photomath            NaN  March 8, 2019      5
# 1                         Photomath            NaN  March 8, 2019      4
# 2                         Photomath            NaN  March 8, 2019      5
# 3                         Photomath            NaN  March 8, 2019      5
# 4                         Photomath            NaN  March 8, 2019      1
# ...                             ...            ...            ...    ...
# 2715298  SoundCloud - Music & Audio  pubgmaster 25    May 3, 2019      1
# 2715299  SoundCloud - Music & Audio   Anjita Sinha    May 3, 2019      4
# 2715300  SoundCloud - Music & Audio     Luis Lucas    May 3, 2019      5
# 2715301  SoundCloud - Music & Audio    Teairo Keys    May 3, 2019      5
# 2715302  SoundCloud - Music & Audio       Ian Libo    May 3, 2019      1
#
#                                                       text         CATEGORY  \
# 0                                                     nice        EDUCATION
# 1                                             very helpful        EDUCATION
# 2        Great App. Detailed answers. Understandable an...        EDUCATION
# 3                                                 great!!!        EDUCATION
# 4                        bakwas hai pura.....time pass hai        EDUCATION
# ...                                                    ...              ...
# 2715298                                             it gay  MUSIC AND AUDIO
# 2715299                                            Love it  MUSIC AND AUDIO
# 2715300  muy bueno me gusta y puedo aguardar la musica ...  MUSIC AND AUDIO
# 2715301                                      love this app  MUSIC AND AUDIO
# 2715302  The app was great and has a very nice selectio...  MUSIC AND AUDIO
#
#                                              processedText
# 0                                                     nice
# 1                                             very helpful
# 2        Great App Detailed answers Understandable answers
# 3                                                    great
# 4                             bakwas hai puratime pass hai
# ...                                                    ...
# 2715298                                             it gay
# 2715299                                            Love it
# 2715300  muy bueno me gusta y puedo aguardar la musica ...
# 2715301                                      love this app
# 2715302  The app was great and has a very nice selectio...
#
# [1114503 rows x 7 columns]

# %% [markdown]
# We should not remove reviews that contain two more words.
# a. In case sentiment analysis needs to be carried , a two word review such as, "Great APP" would help in bossint up the overall sentiment of that review. Ignoring such reviews would probably take away such reviews which would have some meaning in it.

# %%
def recurringCharacters(text):
    for eachWord in text:
        RemoveDuplicates(eachWord)



#         function RemoveDuplicates() {
#     var str = "aaabbbccc";
#     var filtered = str.replace(/[^\w\s]|(.)\1/gi, "");  
#     alert(filtered);
def RemoveDuplicates(eachWord):
    eachWord = str.replace(/[^\w\s]|(.)\1/gi, "")
# Out:
#   File "<ipython-input-109-3a187b644c80>", line 12
#     eachWord = str.replace(/[^\w\s]|(.)\1/gi, "")
#                            ^
# SyntaxError: invalid syntax

# %%
df.groupby(["score"])["text"].count()
# Out:
# score
# 1    150603
# 2     35134
# 3     53981
# 4    111322
# 5    763463
# Name: text, dtype: int64

# %%
df.groupby(["CATEGORY","score"])["CATEGORY"].count()
# Out:
# CATEGORY            score
# EDUCATION           1          7658
#                     2          1843
#                     3          3823
#                     4          9861
#                     5         72645
# ENTERTAINMENT       1         19768
#                     2          5629
#                     3          9690
#                     4         21047
#                     5        127374
# FAMILY              1          9891
#                     2          2367
#                     3          4662
#                     4          9157
#                     5         72706
# FINANCE             1         19929
#                     2          3758
#                     3          4476
#                     4         12253
#                     5        100713
# GAME-ACTION         1         21973
#                     2          4609
#                     3          9413
#                     4         19810
#                     5        153688
# HEALTH AND FITNESS  1         14916
#                     2          4655
#                     3          5879
#                     4         12210
#                     5         72199
# LIFESTYLE           1         28263
#                     2          4019
#                     3          5320
#                     4          9276
#                     5         56050
# MUSIC AND AUDIO     1         28205
#                     2          8254
#                     3         10718
#                     4         17708
#                     5        108088
# Name: CATEGORY, dtype: int64

# %%
Drop duplicates and record how many unique reviews are collected?
2. How many unique apps are in the dataset? How many apps in each of the 8 specified app categories?
3. How many reviews exist in each of the eight app-categories?
4. Based on the contentRating column in the details files for each app, what are the different contentRating groups in each app-category?
5. How many apps exist in each of these contentRating-sub-groups in each app-category?
6. How many reviews in each contentRating-sub-groups in each app-category?

# %% [markdown]
# ##### 1)Drop duplicates and record how many unique reviews are collected?

# %% [markdown]
# ###### Recording of unique number of reviews is done after dropping duplicates which have similar app Title,UserName,score,text and Category and then again dropping duplicates that have the same apptitle and review

# %%
len(df.text.unique())
# Out:
# 673592

# %% [markdown]
# Total number of unique reviews is 673592

# %% [markdown]
# ###### 2. How many unique apps are in the dataset? How many apps in each of the 8 specified app categories?

# %%
print("Number of unique apps are",len(df['appTitle'].unique()))
print("Apps in each of the 8 specified app categories are")
df.groupby("CATEGORY")['appTitle'].nunique()
# Out:
# Number of unique apps are 86
# Apps in each of the 8 specified app categories are
# CATEGORY
# EDUCATION             10
# ENTERTAINMENT         13
# FAMILY                10
# FINANCE               10
# GAME-ACTION           11
# HEALTH AND FITNESS    10
# LIFESTYLE             12
# MUSIC AND AUDIO       11
# Name: appTitle, dtype: int64

# %% [markdown]
# ##### 3. How many reviews exist in each of the eight app-categories?

# %%
df.groupby("CATEGORY")['text'].count()
# Out:
# CATEGORY
# EDUCATION              95830
# ENTERTAINMENT         181303
# FAMILY                 98783
# FINANCE               141129
# GAME-ACTION           209493
# HEALTH AND FITNESS    109859
# LIFESTYLE             102928
# MUSIC AND AUDIO       172973
# Name: text, dtype: int64
